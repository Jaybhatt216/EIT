# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaybhatt216/EIT/blob/main/Raw_scania_train_and_test_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("sample_data/raw_scania_train_data.csv")

# %%
df_test =pd.read_csv("raw_scania_test_data.csv")

# %%
df_train.head(100)
# Out:
#     index class  aa_000 ab_000      ac_000  ...  ee_007  ee_008 ee_009 ef_000 eg_000
# 0       0   neg   76698     na  2130706438  ...  157956   73224      0      0      0
# 1       1   neg   33058     na           0  ...   81140   97576   1500      0      0
# 2       2   neg   41040     na         228  ...  158022   95128    514      0      0
# 3       3   neg      12      0          70  ...       0       0      0      4     32
# 4       4   neg   60874     na        1368  ...  311560  433954   1218      0      0
# ..    ...   ...     ...    ...         ...  ...     ...     ...    ...    ...    ...
# 95     95   neg   42700     na         372  ...  239650  571872   5502      0      0
# 96     96   neg   12494     na          78  ...   47966      46      0      0      0
# 97     97   neg   40576     na           0  ...   64308  102692  11312      0      0
# 98     98   neg   32564     na           0  ...   79058   79682   2284      0      0
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 172 entries, index to eg_000
# dtypes: int64(2), object(170)
# memory usage: 78.7+ MB

# %%
df = df_train.fillna(df_train.mean())
df.head(100)
# Out:
#     index class  aa_000 ab_000      ac_000  ...  ee_007  ee_008 ee_009 ef_000 eg_000
# 0       0   neg   76698     na  2130706438  ...  157956   73224      0      0      0
# 1       1   neg   33058     na           0  ...   81140   97576   1500      0      0
# 2       2   neg   41040     na         228  ...  158022   95128    514      0      0
# 3       3   neg      12      0          70  ...       0       0      0      4     32
# 4       4   neg   60874     na        1368  ...  311560  433954   1218      0      0
# ..    ...   ...     ...    ...         ...  ...     ...     ...    ...    ...    ...
# 95     95   neg   42700     na         372  ...  239650  571872   5502      0      0
# 96     96   neg   12494     na          78  ...   47966      46      0      0      0
# 97     97   neg   40576     na           0  ...   64308  102692  11312      0      0
# 98     98   neg   32564     na           0  ...   79058   79682   2284      0      0
# ...

# %%
df3 = df_train.fillna(df_train.median())
df.head(100)
# Out:
#     index class  aa_000 ab_000      ac_000  ...  ee_007  ee_008 ee_009 ef_000 eg_000
# 0       0   neg   76698     na  2130706438  ...  157956   73224      0      0      0
# 1       1   neg   33058     na           0  ...   81140   97576   1500      0      0
# 2       2   neg   41040     na         228  ...  158022   95128    514      0      0
# 3       3   neg      12      0          70  ...       0       0      0      4     32
# 4       4   neg   60874     na        1368  ...  311560  433954   1218      0      0
# ..    ...   ...     ...    ...         ...  ...     ...     ...    ...    ...    ...
# 95     95   neg   42700     na         372  ...  239650  571872   5502      0      0
# 96     96   neg   12494     na          78  ...   47966      46      0      0      0
# 97     97   neg   40576     na           0  ...   64308  102692  11312      0      0
# 98     98   neg   32564     na           0  ...   79058   79682   2284      0      0
# ...

# %%
df3.corr()
# Out:
#            index    aa_000
# index   1.000000 -0.008329
# aa_000 -0.008329  1.000000

# %%
df3.describe()
# Out:
#               index        aa_000
# count  60000.000000  6.000000e+04
# mean   29999.500000  5.933650e+04
# std    17320.652413  1.454301e+05
# min        0.000000  0.000000e+00
# 25%    14999.750000  8.340000e+02
# 50%    29999.500000  3.077600e+04
# 75%    44999.250000  4.866800e+04
# max    59999.000000  2.746564e+06

# %%
df.describe()
# Out:
#               index        aa_000
# count  60000.000000  6.000000e+04
# mean   29999.500000  5.933650e+04
# std    17320.652413  1.454301e+05
# min        0.000000  0.000000e+00
# 25%    14999.750000  8.340000e+02
# 50%    29999.500000  3.077600e+04
# 75%    44999.250000  4.866800e+04
# max    59999.000000  2.746564e+06

# %%
df.corr()
# Out:
#            index    aa_000
# index   1.000000 -0.015224
# aa_000 -0.015224  1.000000

# %%
df.replace(np.nan, 0,inplace=True)
df.head()
# Out:
#    index class  aa_000 ab_000      ac_000  ...  ee_007  ee_008 ee_009 ef_000 eg_000
# 0      0   neg   76698     na  2130706438  ...  157956   73224      0      0      0
# 1      1   neg   33058     na           0  ...   81140   97576   1500      0      0
# 2      2   neg   41040     na         228  ...  158022   95128    514      0      0
# 3      3   neg      12      0          70  ...       0       0      0      4     32
# 4      4   neg   60874     na        1368  ...  311560  433954   1218      0      0
#
# [5 rows x 172 columns]

# %%
pd.plotting.scatter_matrix(df, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0fedcee240>,
# ...
#       dtype=object)

# %%
df['class'].head(100
                 )
# Out:
# 0     neg
# 1     neg
# 2     neg
# 3     neg
# 4     neg
#      ...
# 95    neg
# 96    neg
# 97    neg
# 98    neg
# 99    neg
# Name: class, Length: 100, dtype: object

# %%
df['class'] = df['class'].head(100)
df['aa_000'] = df['aa_000'].head(100)
to_plot = df.groupby('class')
to_plot.plot(kind='barh', figsize=(12,6))
# Out:
# class
# neg    AxesSubplot(0.125,0.125;0.775x0.755)
# pos    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df['class'] = df2['class'].head(100)
df['aa_000'] = df2['aa_000'].head(100)
to_plot = df.groupby('class')
to_plot.plot(kind='barh', figsize=(20,18))

# %%
corrMatrix = df.corr()

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(corrMatrix, annot=True,ax=ax)
plt.show()

# %%
plt.scatter(df['index'],df['aa_000'])
plt.show()

# %%
sns.displot(df['aa_000'])

# %%
sns.lmplot(x='index', y='aa_000', 
           data=df, height=12)

# %%
df.set_index('class')['aa_000'].plot()

# %%
df.set_index('index')['aa_000'].plot()

# %% [markdown]
# Test EDA

# %%
df_test.head(5)
# Out:
#    index class  aa_000 ab_000 ac_000  ...  ee_007  ee_008 ee_009 ef_000 eg_000
# 0      0   neg      60      0     20  ...      88       0      0      0      0
# 1      1   neg      82      0     68  ...     462       0      0      0      0
# 2      2   neg   66002      2    212  ...  153680     516      0      0      0
# 3      3   neg   59816     na   1010  ...  210074  281662   3232      0      0
# 4      4   neg    1814     na    156  ...     482      76      0      0      0
#
# [5 rows x 172 columns]

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Columns: 172 entries, index to eg_000
# dtypes: int64(2), object(170)
# memory usage: 21.0+ MB

# %%
df2 = df_test.fillna(df_test.mean())
df2.head(5)
# Out:
#    index class  aa_000 ab_000 ac_000  ...  ee_007  ee_008 ee_009 ef_000 eg_000
# 0      0   neg      60      0     20  ...      88       0      0      0      0
# 1      1   neg      82      0     68  ...     462       0      0      0      0
# 2      2   neg   66002      2    212  ...  153680     516      0      0      0
# 3      3   neg   59816     na   1010  ...  210074  281662   3232      0      0
# 4      4   neg    1814     na    156  ...     482      76      0      0      0
#
# [5 rows x 172 columns]

# %%
df2.describe()
# Out:
#               index        aa_000
# count  16000.000000  1.600000e+04
# mean    7999.500000  6.799698e+04
# std     4618.946489  5.035350e+05
# min        0.000000  0.000000e+00
# 25%     3999.750000  9.280000e+02
# 50%     7999.500000  3.098200e+04
# 75%    11999.250000  4.947900e+04
# max    15999.000000  4.294967e+07

# %%
df2.corr
# Out:
# <bound method DataFrame.corr of        index class  aa_000 ab_000  ...  ee_008 ee_009 ef_000 eg_000
# 0          0   neg      60      0  ...       0      0      0      0
# 1          1   neg      82      0  ...       0      0      0      0
# 2          2   neg   66002      2  ...     516      0      0      0
# 3          3   neg   59816     na  ...  281662   3232      0      0
# 4          4   neg    1814     na  ...      76      0      0      0
# ...      ...   ...     ...    ...  ...     ...    ...    ...    ...
# 15995  15995   neg   81852     na  ...  960024  25566      0      0
# 15996  15996   neg      18      0  ...       0      0      0      0
# 15997  15997   neg   79636     na  ...  358934  19548      0      0
# 15998  15998   neg     110     na  ...      74      0      0      0
# 15999  15999   neg       8      0  ...       0      0      0      0
#
# [16000 rows x 172 columns]>

# %%
df2.replace(np.nan, 0)

# %%
df2.corr

# %%
pd.plotting.scatter_matrix(df2, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0fee429c88>,
# ...
#       dtype=object)

# %%
df2['class'] = df2['class'].head(100)
df2['aa_000'] = df2['aa_000'].head(100)
to_plot = df.groupby('class')
to_plot.plot(kind='barh', figsize=(20,18))
# Out:
# class
# neg    AxesSubplot(0.125,0.125;0.775x0.755)
# pos    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
corrMatrix2 = df2.corr()

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(corrMatrix2, annot=True,ax=ax)
plt.show()

# %%
plt.scatter(df2['index'],df2['aa_000'])
plt.show()

# %%
sns.displot(df2['aa_000'])

# %%
sns.lmplot(x='index', y='aa_000', 
           data=df, height=12)

# %%
df2.set_index('class')['aa_000'].plot()

# %%
df.set_index('index')['aa_000'].plot()
