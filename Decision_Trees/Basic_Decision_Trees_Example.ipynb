# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
golf = pd.read_csv('./golf.csv')
golf = golf[1:14]
print(golf.head())
# Out:
#     Outlook  Temp_Num Temp_Nom  Hum_Num Hum_Nom  Windy Play
# 1  overcast        64     cool       65  normal   True  yes
# 2  overcast        72     mild       90    high   True  yes
# 3  overcast        81      hot       75  normal  False  yes
# 4     rainy        70     mild       96    high  False  yes
# 5     rainy        68     cool       80  normal  False  yes

# %%
columns = ["Outlook", "Temp_Nom", "Hum_Nom", "Windy", "Play"]
golf = golf[columns]
print(golf)
# Out:
#      Outlook Temp_Nom Hum_Nom  Windy Play
# 1   overcast     cool  normal   True  yes
# 2   overcast     mild    high   True  yes
# 3   overcast      hot  normal  False  yes
# 4      rainy     mild    high  False  yes
# 5      rainy     cool  normal  False  yes
# 6      rainy     cool  normal   True   no
# 7      rainy     mild  normal  False  yes
# 8      rainy     mild    high   True   no
# 9      sunny      hot    high  False   no
# 10     sunny      hot    high   True   no
# 11     sunny     mild    high  False   no
# 12     sunny     cool  normal  False  yes
# 13     sunny     mild  normal   True  yes

# %%
def entropy(y):
  if sum(y == 'no') == 0 or sum(y == 'yes') == 0:
    return 0

  E = - (sum(y == 'no') / len(y) * np.log2(sum(y == 'no') / len(y)) + sum(y == 'yes')/len(y) * np.log2(sum(y == 'yes') / len(y)))
  return E

# %%
print(entropy(golf.Play))
# Out:
# 0.9612366047228759

# %%
def informationGain(left, right):
    before = pd.concat([left, right])
    eBefore = entropy(before.Play)
    print("Entropy Before:", eBefore)
    if len(left.Play) != 0:
        eLeft = entropy(left.Play)*(len(left.Play)/len(before.Play))
    else:
        eLeft = 0
    print("Entropy of Left:", eLeft)
    if len(right.Play) != 0:
        eRight = entropy(right.Play)*(len(right.Play)/len(before.Play))
    else:
        eRight = 0
    print("Entropy of Right:", eRight)
    eAfter = eLeft + eRight
    print("Entropy After:", eAfter)
    IG = eBefore - eAfter
    return IG

# %%
left = golf[golf.Windy == True]
right = golf[golf.Windy == False]
print(informationGain(left, right))
# Out:
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.46153846153846156
# Entropy of Right: 0.4647572292281859
# Entropy After: 0.9262956907666475
# 0.03494091395622834

# %%
def split(df):
    features = [column for column in df.columns if column != "Play"]
    feature_dict = {}
    for feature in features:
        feature_dict[feature] = [value for value in df[feature].unique()]
    IG = 0
    splits = []
    for feature in features:
        for value in feature_dict[feature]:
            print(value)
            print("Best IG:",IG)
            left = df[df[feature] == value]
            right = df[df[feature] != value]
            temp_ig = informationGain(left, right)
            print("Temp IG:", temp_ig)
            if temp_ig > IG:
                bestSplit = (feature, value)
                IG = temp_ig
                print("New Best Information Gain:", IG)
                print(bestSplit)
    if IG != 0:
        left = df[df[bestSplit[0]] == bestSplit[1]]
        right = df[df[bestSplit[0]] != bestSplit[1]]
    if len(left.Play != 0):
        if entropy(left.Play) != 0:
            splits.append(split(left))
    if len(right.Play != 0):
        if entropy(right.Play) != 0:
            splits.append(split(right))
    splits.append(bestSplit)
    return splits

# %%
split(golf)
# Out:
# overcast
# Best IG: 0
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.0
# Entropy of Right: 0.7692307692307693
# Entropy After: 0.7692307692307693
# Temp IG: 0.1920058354921066
# New Best Information Gain: 0.1920058354921066
# ('Outlook', 'overcast')
# rainy
# Best IG: 0.1920058354921066
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.3734425363287187
# Entropy of Right: 0.5873440017999785
# Entropy After: 0.9607865381286972
# Temp IG: 0.00045006659417867745
# sunny
# Best IG: 0.1920058354921066
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.3734425363287187
# Entropy of Right: 0.4992480765902356
# Entropy After: 0.8726906129189543
# Temp IG: 0.08854599180392153
# cool
# Best IG: 0.1920058354921066
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.2496240382951178
# Entropy of Right: 0.6861295798879999
# Entropy After: 0.9357536181831178
# Temp IG: 0.025482986539758112
# mild
# Best IG: 0.1920058354921066
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.4238288464866875
# Entropy of Right: 0.530507457864597
# Entropy After: 0.9543363043512845
# Temp IG: 0.006900300371591395
# hot
# Best IG: 0.1920058354921066
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.21191442324334375
# Entropy of Right: 0.6779160763313021
# Entropy After: 0.8898304995746459
# Temp IG: 0.07140610514822998
# normal
# Best IG: 0.1920058354921066
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.3185930346212532
# Entropy of Right: 0.4238288464866875
# Entropy After: 0.7424218811079407
# Temp IG: 0.21881472361493515
# New Best Information Gain: 0.21881472361493515
# ('Hum_Nom', 'normal')
# high
# Best IG: 0.21881472361493515
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.4238288464866875
# Entropy of Right: 0.3185930346212532
# Entropy After: 0.7424218811079407
# Temp IG: 0.21881472361493515
# True
# Best IG: 0.21881472361493515
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.46153846153846156
# Entropy of Right: 0.4647572292281859
# Entropy After: 0.9262956907666475
# Temp IG: 0.03494091395622834
# False
# Best IG: 0.21881472361493515
# Entropy Before: 0.9612366047228759
# Entropy of Left: 0.4647572292281859
# Entropy of Right: 0.46153846153846156
# Entropy After: 0.9262956907666475
# Temp IG: 0.03494091395622834
# overcast
# Best IG: 0
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.0
# Entropy of Right: 0.5156629249195446
# Entropy After: 0.5156629249195446
# Temp IG: 0.0760098536627829
# New Best Information Gain: 0.0760098536627829
# ('Outlook', 'overcast')
# rainy
# Best IG: 0.0760098536627829
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.39355535745192405
# Entropy of Right: 0.0
# Entropy After: 0.39355535745192405
# Temp IG: 0.19811742113040343
# New Best Information Gain: 0.19811742113040343
# ('Outlook', 'rainy')
# sunny
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.0
# Entropy of Right: 0.5156629249195446
# Entropy After: 0.5156629249195446
# Temp IG: 0.0760098536627829
# cool
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.46358749969093305
# Entropy of Right: 0.0
# Entropy After: 0.46358749969093305
# Temp IG: 0.12808527889139443
# hot
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.0
# Entropy of Right: 0.5571620756985892
# Entropy After: 0.5571620756985892
# Temp IG: 0.03451070288373825
# mild
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.0
# Entropy of Right: 0.5156629249195446
# Entropy After: 0.5156629249195446
# Temp IG: 0.0760098536627829
# normal
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.5916727785823275
# Entropy of Right: 0
# Entropy After: 0.5916727785823275
# Temp IG: 0.0
# True
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.39355535745192405
# Entropy of Right: 0.0
# Entropy After: 0.39355535745192405
# Temp IG: 0.19811742113040343
# False
# Best IG: 0.19811742113040343
# Entropy Before: 0.5916727785823275
# Entropy of Left: 0.0
# Entropy of Right: 0.39355535745192405
# Entropy After: 0.39355535745192405
# Temp IG: 0.19811742113040343
# rainy
# Best IG: 0
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.9182958340544896
# Entropy of Right: 0
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# cool
# Best IG: 0
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.6666666666666666
# Entropy of Right: 0.0
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# New Best Information Gain: 0.2516291673878229
# ('Temp_Nom', 'cool')
# mild
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.6666666666666666
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# normal
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.9182958340544896
# Entropy of Right: 0
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# False
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.0
# Entropy After: 0.0
# Temp IG: 0.9182958340544896
# New Best Information Gain: 0.9182958340544896
# ('Windy', False)
# True
# Best IG: 0.9182958340544896
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.0
# Entropy After: 0.0
# Temp IG: 0.9182958340544896
# overcast
# Best IG: 0
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.6016067457394686
# Entropy After: 0.6016067457394686
# Temp IG: 0.31668908831502096
# New Best Information Gain: 0.31668908831502096
# ('Outlook', 'overcast')
# rainy
# Best IG: 0.31668908831502096
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.3333333333333333
# Entropy of Right: 0.5408520829727552
# Entropy After: 0.8741854163060885
# Temp IG: 0.044110417748401076
# sunny
# Best IG: 0.31668908831502096
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.4591479170272448
# Entropy After: 0.4591479170272448
# Temp IG: 0.4591479170272448
# New Best Information Gain: 0.4591479170272448
# ('Outlook', 'sunny')
# mild
# Best IG: 0.4591479170272448
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.6666666666666666
# Entropy of Right: 0.0
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# hot
# Best IG: 0.4591479170272448
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.6666666666666666
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# high
# Best IG: 0.4591479170272448
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.9182958340544896
# Entropy of Right: 0
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# True
# Best IG: 0.4591479170272448
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.4591479170272448
# Entropy of Right: 0.4591479170272448
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# False
# Best IG: 0.4591479170272448
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.4591479170272448
# Entropy of Right: 0.4591479170272448
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# overcast
# Best IG: 0
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.6666666666666666
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# New Best Information Gain: 0.2516291673878229
# ('Outlook', 'overcast')
# rainy
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.6666666666666666
# Entropy of Right: 0.0
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# mild
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.9182958340544896
# Entropy of Right: 0
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# high
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.9182958340544896
# Entropy of Right: 0
# Entropy After: 0.9182958340544896
# Temp IG: 0.0
# True
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.6666666666666666
# Entropy of Right: 0.0
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# False
# Best IG: 0.2516291673878229
# Entropy Before: 0.9182958340544896
# Entropy of Left: 0.0
# Entropy of Right: 0.6666666666666666
# Entropy After: 0.6666666666666666
# Temp IG: 0.2516291673878229
# rainy
# Best IG: 0
# Entropy Before: 1.0
# Entropy of Left: 1.0
# Entropy of Right: 0
# Entropy After: 1.0
# Temp IG: 0.0
# mild
# Best IG: 0
# Entropy Before: 1.0
# Entropy of Left: 1.0
# Entropy of Right: 0
# Entropy After: 1.0
# Temp IG: 0.0
# high
# Best IG: 0
# Entropy Before: 1.0
# Entropy of Left: 1.0
# Entropy of Right: 0
# Entropy After: 1.0
# Temp IG: 0.0
# False
# Best IG: 0
# Entropy Before: 1.0
# Entropy of Left: 0.0
# Entropy of Right: 0.0
# Entropy After: 0.0
# Temp IG: 1.0
# New Best Information Gain: 1.0
# ('Windy', False)
# True
# Best IG: 1.0
# Entropy Before: 1.0
# Entropy of Left: 0.0
# Entropy of Right: 0.0
# Entropy After: 0.0
# Temp IG: 1.0
# [[[('Windy', False)], ('Outlook', 'rainy')],
#  [[[('Windy', False)], ('Outlook', 'overcast')], ('Outlook', 'sunny')],
#  ('Hum_Nom', 'normal')]
